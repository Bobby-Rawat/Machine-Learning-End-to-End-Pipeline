# %%
import joblib, pickle,pandas as pd, numpy as np

# %%
# !pip install gdown;

# %%
# Scaler file
# !gdown --id 1nz8nFhCmqqhyv1B1Orw57BsB0AYDsxB- -O svm_scaler.pkl

# SVC model file
# !gdown --id 1-1oRB0A3q4aasBpGSGrUMTlTSgc_jEX_ -O svc_pickle_model.pkl

# Form code file
# !gdown --id 1-6gMwq0de_c5qxDDqtGmhnXYSlL5eU9G -O form.pkl
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1nz8nFhCmqqhyv1B1Orw57BsB0AYDsxB-
# To: /content/svm_scaler.pkl
# 100% 1.31k/1.31k [00:00<00:00, 4.74MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-1oRB0A3q4aasBpGSGrUMTlTSgc_jEX_
# To: /content/svc_pickle_model.pkl
# 100% 90.8k/90.8k [00:00<00:00, 95.3MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# ...

# %%
person_scaler = joblib.load('svm_scaler.pkl')
svc_pickle_model = joblib.load('svc_pickle_model.pkl')
Form = joblib.load('form.pkl')

# %%
exec(Form)
# Out:
# Enter the total area (290-360): 300
# Enter the number of rooms (5-9): 7
# Enter the number of bedrooms (2-8): 5
# Enter the number of bedrooms with washrooms (1-7): 6
# Enter the number of washrooms (3-8): 5
# Enter the roof area (0-120): 60
# Enter the lawn area (70-110): 80
# Enter the number of floors (1-8): 7
# Enter the API (59-99): 65
# Enter the ANB (1-6): 6
# Enter the expected value (0-2041): 1400
# The predicted class is: ['C:- 2']

# %% [markdown]
# <h1><b> Thank You ! <b></h1>
